# %%
# !pip install import_ipynb
# !pip3 install wheel
# !pip install pygco
# Out:
# Requirement already satisfied: import_ipynb in /anaconda3/lib/python3.7/site-packages (0.1.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/site-packages (0.33.4)
# Requirement already satisfied: pygco in /anaconda3/lib/python3.7/site-packages (0.0.16)
# Requirement already satisfied: cython in /anaconda3/lib/python3.7/site-packages (from pygco) (0.29.6)

# %%
# %run preprocess.ipynb
# %run clustering.ipynb
# %run graph_cut.ipynb
# %run ImageMetric.ipynb
# Out:
# Requirement already satisfied: opencv-python==3.4.2.16 in /anaconda3/lib/python3.7/site-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.14.5 in /anaconda3/lib/python3.7/site-packages (from opencv-python==3.4.2.16) (1.16.2)
# Requirement already satisfied: opencv-contrib-python==3.4.2.16 in /anaconda3/lib/python3.7/site-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.14.5 in /anaconda3/lib/python3.7/site-packages (from opencv-contrib-python==3.4.2.16) (1.16.2)
# Requirement already satisfied: opencv-python==3.4.2.16 in /anaconda3/lib/python3.7/site-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.14.5 in /anaconda3/lib/python3.7/site-packages (from opencv-python==3.4.2.16) (1.16.2)
# Requirement already satisfied: opencv-contrib-python==3.4.2.16 in /anaconda3/lib/python3.7/site-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.14.5 in /anaconda3/lib/python3.7/site-packages (from opencv-contrib-python==3.4.2.16) (1.16.2)
# Requirement already satisfied: opencv-python in /anaconda3/lib/python3.7/site-packages (3.4.2.16)
# Requirement already satisfied: numpy>=1.14.5 in /anaconda3/lib/python3.7/site-packages (from opencv-python) (1.16.2)

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import svm
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import LinearSVC
import pickle

# %%
def create_train_set(filename,number_of_colors = 32,window = 15):
    size = 600, 400
    im = Image.open(filename)
    im_resized = im.resize(size, Image.ANTIALIAS)
    im_lab = cv2.cvtColor(np.array(im_resized),cv2.COLOR_BGR2LAB)
    im_lab_np = np.array(im_lab)
    grayscale_img = im_lab[:,:,0]
    y,centers = create_label(im_lab_np[:,:,1:],number_of_colors ,window)#number of colors and window size
    feature_vector = all_feature_vector(grayscale_img,window)#window
    feature_vector = np.transpose(feature_vector)
    min_max_scaler = MinMaxScaler()
    feature_vector = min_max_scaler.fit_transform(feature_vector)
    pca = PCA(n_components=30)
    pca.fit(feature_vector)
    print(np.sum(pca.explained_variance_ratio_))
    x = pca.transform(feature_vector)
    return x , y,centers,pca,min_max_scaler,grayscale_img[int(window/2):-int(window/2), int(window/2):-int(window/2)]

# %%
def create_test_set(grayscale_img,pca,scaler,window=15):
    feature_vector = all_feature_vector(grayscale_img,window)#window
    feature_vector = np.transpose(feature_vector)
    feature_vector = scaler.transform(feature_vector)
    x_test = pca.transform(feature_vector)
    return x_test

# %%
def train_svm(x,y,number_of_colors, c = 1):
    svm_arr = []
    for i in range(number_of_colors):
        y_train = (y == i).astype(int)
        svm = LinearSVC(dual=False,C=c,class_weight = "balanced")
        svm.fit(x,  y_train)
        svm_arr.append(svm)
    return svm_arr

# %%
def test_svm(svm_arr,feature_vector,row_number,column_number):
    margins_arr = []
    for i in range(row_number*column_number):
        margins = []
        for svm in svm_arr:
            marg = -1.0*(svm.decision_function(feature_vector[i:i+1,:])[0])
            margins.append(marg)
        margins_arr.append(margins)
        
    margins_arr = np.array(margins_arr)
    return np.reshape(margins_arr,(row_number,column_number,-1))

# %%
def create_image(grayscale_img, centers,result):
    image = np.zeros((grayscale_img.shape[0],grayscale_img.shape[1],3))
    for i in range(grayscale_img.shape[0]):
        for k in range(grayscale_img.shape[1]):
            image[i,k,0] = grayscale_img[i,k]
            image[i,k,1:] = centers[result[i,k]]
    return image

# %%
def lab_to_rgb(image):
    new_image_show = np.zeros((image.shape[0],image.shape[1],3)) 
    new_image_show[:,:,0] = image[:,:,0] *100 /255
    new_image_show[:,:,1] =image[:,:,1] - 128
    new_image_show[:,:,2] =image[:,:,2] - 128
    a = lab2rgb(new_image_show)
    return np.flip(a,axis=2)

# %%
def convert_test_image(filename):
    size = 600, 400
    im = Image.open(filename)
    im_resized = im.resize(size, Image.ANTIALIAS)
    im_lab = cv2.cvtColor(np.array(im_resized),cv2.COLOR_BGR2LAB)
    im_lab_np = np.array(im_lab)
    grayscale_img = im_lab[:,:,0]
    return grayscale_img,im_resized,im_lab[:,:,1:]

# %%
x,y,centers,pca,min_max_scaler,gray_scale = create_train_set("train.jpeg",number_of_colors = 32,window=15)#pca will be used for the test projection
# Out:
# 0.7592401148612602

# %%
grayscale_test, original_test,original_ab = convert_test_image("test1.png")

# %%
x_test = create_test_set(grayscale_test,pca,min_max_scaler,window=15)

# %%
svm_arr = train_svm(x,y.flatten(),32,c=1)

# %%
window = 15
margin = test_svm(svm_arr,x_test,grayscale_test.shape[0]-window+1,grayscale_test.shape[1]-window+1)

# %%
result = graph_cut2(grayscale_test[int(window/2):-int(window/2), int(window/2):-int(window/2)], margin,centers,32,alpha=8)

# %%
predicted_image = create_image(grayscale_test[int(window/2):-int(window/2), int(window/2):-int(window/2)], centers,result)

# %%
#print(np.sum(predicted_rgb < 0))
predicted_rgb = lab_to_rgb(predicted_image)
plt.imshow(predicted_rgb)
# Out:
# /anaconda3/lib/python3.7/site-packages/skimage/color/colorconv.py:993: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)

# %%
error,best_case = get_error(predicted_image[:,:,1:],original_ab[int(window/2):-int(window/2), int(window/2):-int(window/2)],centers,grayscale_test[int(window/2):-int(window/2), int(window/2):-int(window/2)])
print("Error: ")
print(error)
# Out:
# Error:
# 21.523353840924596

# %%
predicted_lab = np.zeros((386,586,3))
predicted_lab[:,:,0] = grayscale_test[int(window/2):-int(window/2), int(window/2):-int(window/2)]
for i in range(386):
    for k in range(586):
        predicted_lab[i,k,1:] = centers[np.argmin(margin[i,k])]

# %%
predicted_rgb = lab_to_rgb(predicted_lab)
plt.imshow(predicted_rgb)
# Out:
# /anaconda3/lib/python3.7/site-packages/skimage/color/colorconv.py:993: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   warn('Color data out of range: Z < 0 in %s pixels' % invalid[0].size)

# %%
plt.imsave("result.jpg",predicted_rgb)
#necessary = (svm_arr, margin,centers)
# save the classifier
#with open('necessary.pkl', 'wb') as fid:
#     pickle.dump(necessary , fid)

# %%
#with open('necessary.pkl', 'rb') as fid:
#    necessary= pickle.load(fid)

# %%
predicted_rgb = lab_to_rgb(best_case)
plt.imshow(predicted_rgb)

# %%
predicted_rgb
# Out:
# array([[[0.79484815, 0.94583255, 0.99453462],
#         [0.799132  , 0.95024399, 0.99901896],
#         [0.799132  , 0.95024399, 0.99901896],
#         ...,
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ]],
#
#        [[0.799132  , 0.95024399, 0.99901896],
#         [0.799132  , 0.95024399, 0.99901896],
#         [0.799132  , 0.95024399, 0.99901896],
#         ...,
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ]],
#
#        [[0.799132  , 0.95024399, 0.99901896],
#         [0.799132  , 0.95024399, 0.99901896],
#         [0.799132  , 0.95024399, 0.99901896],
#         ...,
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ],
#         [0.94530269, 0.99627079, 1.        ]],
#
#        ...,
#
#        [[0.62215878, 0.78397881, 0.41984699],
#         [0.61399184, 0.77537304, 0.41130194],
#         [0.65914831, 0.82290439, 0.45829783],
#         ...,
#         [0.49224881, 0.71372302, 0.31877936],
#         [0.51599265, 0.7393041 , 0.34523917],
#         [0.60584445, 0.76678358, 0.40275454]],
#
#        [[0.61807287, 0.77967389, 0.41557468],
#         [0.58556243, 0.74538189, 0.38136781],
#         [0.64677553, 0.80989315, 0.44547849],
#         ...,
#         [0.47652504, 0.69675228, 0.30098463],
#         [0.58960888, 0.74965396, 0.3856479 ],
#         [0.53992278, 0.76503306, 0.37149851]],
#
#        [[0.70069447, 0.86653136, 0.50108445],
#         [0.60991569, 0.77107627, 0.4070286 ],
#         [0.60584445, 0.76678358, 0.40275454],
#         ...,
#         [0.50014248, 0.72223348, 0.32762657],
#         [0.51996817, 0.74358205, 0.3496276 ],
#         [0.55597778, 0.78226674, 0.38892708]]])

# %%
margin.shape
# Out:
# (386, 586, 32)

# %%
plt.imshow(cv2.cvtColor(np.uint8(predicted_lab), cv2.CV_Lab2BRG))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-b38961700c96> in <module>
# ----> 1 plt.imshow(cv2.cvtColor(np.uint8(predicted_lab), cv2.CV_Lab2BRG))
#
# AttributeError: module 'cv2.cv2' has no attribute 'CV_Lab2BRG'
